# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('IPL_BAll_by_Ball_2008_2022.csv')
df = pd.DataFrame(data)
df.head()
df.info()
df.shape
df.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 225954 entries, 0 to 225953
# Data columns (total 17 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   ID                 225954 non-null  int64
#  1   innings            225954 non-null  int64
#  2   overs              225954 non-null  int64
#  3   ballnumber         225954 non-null  int64
#  4   batter             225954 non-null  str
#  5   bowler             225954 non-null  str
#  6   non-striker        225954 non-null  str
#  7   extra_type         12049 non-null   str
#  8   batsman_run        225954 non-null  int64
#  9   extras_run         225954 non-null  int64
#  10  total_run          225954 non-null  int64
#  11  non_boundary       225954 non-null  int64
#  12  isWicketDelivery   225954 non-null  int64
#  13  player_out         11151 non-null   str
#  14  kind               11151 non-null   str
#  15  fielders_involved  7988 non-null    str
# ...

# %%
df['batter'].value_counts()
eligible_batsman = df['batter'].value_counts()[df['batter'].value_counts() > 100].index
eligible_batsman

new_df = df[df['batter'].isin(eligible_batsman)]
# new_df.info()
new_df.shape

run_b = new_df.groupby(df['batter'])['batsman_run'].sum()

out_batsman = df['player_out'].value_counts()
out_ser = out_batsman[out_batsman.index.isin(eligible_batsman)]
out_ser
# Out:
# player_out
# RG Sharma          194
# V Kohli            183
# RV Uthappa         180
# S Dhawan           179
# SK Raina           171
#                   ...
# B Sai Sudharsan      4
# DJ Harris            4
# AC Voges             4
# NK Patel             4
# MN van Wyk           3
# Name: count, Length: 265, dtype: int64

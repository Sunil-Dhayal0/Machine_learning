# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv('h_w.csv')
df = pd.DataFrame(data)
df
# Out:
#     Age  Height
# 0    10     138
# 1    11     138
# 2    12     138
# 3    13     139
# 4    14     139
# ..  ...     ...
# 66   76     204
# 67   77     205
# 68   78     206
# 69   79     207
# 70   80     208
#
# [71 rows x 2 columns]

# %%
sns.pairplot(df)

# %%
X = df.iloc[:,:-1].values
Y = df.iloc[:,-1].values

####------train test
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=42)
model = LinearRegression()
model.fit(X_train,Y_train)
####----------model evaluation
from sklearn.metrics import mean_squared_error
y_p = model.predict(X_test)
mean_squared_error(Y_test,y_p)
# Out:
# 47.378497952571315

# %%
#######-------poly regresion
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=2)
x_poly = poly.fit_transform(X)
X_train,X_test,Y_train,Y_test = train_test_split(x_poly,Y,test_size=0.2,random_state=42)

model.fit(X_train,Y_train)
y_p = model.predict(X_test)
from sklearn.metrics import r2_score
r2_score(y_p,Y_test)
# Out:
# 0.981423784401853

# %%
X_grid = np.arange(X.min(),X.max(),0.1)
X_grid = X_grid.reshape(len(X_grid),1)
plt.scatter(X,Y,color='red')
plt.plot(X_grid,model.predict(poly.fit_transform(X_grid)),color='blue')
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import datasets
dibaties = datasets.load_diabetes()

df = pd.DataFrame(dibaties)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 9
#       5
#       6 from sklearn import datasets
#       7 dibaties = datasets.load_diabetes()
#       8
# ----> 9 df = pd.DataFrame(dibaties)
#      10 df
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:769, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     765             )
#     766
#     767         elif isinstance(data, dict):
#     768             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 769             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy)
#     770         elif isinstance(data, ma.MaskedArray):
#     771             from numpy.ma import mrecords
#     772
#
# ...
